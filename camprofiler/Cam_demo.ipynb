# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import camprofiler as cp

# %%
cam = Cam.Cam(size=60)

# %%
plt.plot(cam.profile)

# %%
new_profile = np.array([0, 1, 2, 1])
cam.fit_profile_polynomial_with_points(new_profile, start=180, end=360, degree=2)
plt.plot(cam.profile)
